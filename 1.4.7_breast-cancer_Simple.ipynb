# %%
# import the dataset
import pandas as pd
df_train = pd.read_csv('d:/Data/Python2Kaggle/Breast-Cancer/breast-cancer-train.csv')
df_test = pd.read_csv('d:/Data/Python2Kaggle/Breast-Cancer/breast-cancer-test.csv')
df_test_negative = df_test.loc[df_test['Type']  == 0][['Clump Thickness','Cell Size']]
df_test_positive = df_test.loc[df_test['Type'] == 1][['Clump Thickness','Cell Size']]

# %%
# plot the scatter plot
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(df_test_negative['Clump Thickness'], df_test_negative['Cell Size'], marker='o', s=200, c='red')
plt.scatter(df_test_positive['Clump Thickness'], df_test_positive['Cell Size'], marker='x', s=150, c='black')
plt.xlabel('Clump Thickness')
plt.ylabel('Cell Size')
# Out:
# Text(0,0.5,'Cell Size')

# %%
# test to plot a line
import numpy as np
intercept = np.random.random([1])
coef = np.random.random([2])
lx = np.arange(0, 12)
print(intercept)
print(coef)
ly = (-intercept - lx * coef[0]) / coef[1]
plt.plot(lx, ly, c = 'yellow')
# Out:
# [0.76011727]
# [0.19822168 0.33952928]

# %%
# run model on 10 samples and show the accuracy.
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(df_train[['Clump Thickness', 'Cell Size']][:10], df_train['Type'][:10])
print ('Testing accuracy (10 training samples):', lr.score(df_test[['Clump Thickness', 'Cell Size']], df_test['Type']))

# plot the scatter plot
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(df_test_negative['Clump Thickness'], df_test_negative['Cell Size'], marker='o', s=200, c='red')
plt.scatter(df_test_positive['Clump Thickness'], df_test_positive['Cell Size'], marker='x', s=150, c='black')
plt.xlabel('Clump Thickness')
plt.ylabel('Cell Size')

# plot the line generated by the 10-sample model
intercept = lr.intercept_
coef = lr.coef_[0, :]
ly = (-intercept - lx * coef[0]) / coef[1]
plt.plot(lx, ly, c ='green')
# Out:
# Testing accuracy (10 training samples): 0.8685714285714285

# %%
# run model on 10 samples and show the accuracy.
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(df_train[['Clump Thickness', 'Cell Size']], df_train['Type'])
print ('Testing accuracy (all training samples):', lr.score(df_test[['Clump Thickness', 'Cell Size']], df_test['Type']))

# plot the scatter plot
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(df_test_negative['Clump Thickness'], df_test_negative['Cell Size'], marker='o', s=200, c='red')
plt.scatter(df_test_positive['Clump Thickness'], df_test_positive['Cell Size'], marker='x', s=150, c='black')
plt.xlabel('Clump Thickness')
plt.ylabel('Cell Size')

# plot the line generated by the 10-sample model
intercept = lr.intercept_
coef = lr.coef_[0, :]
ly = (-intercept - lx * coef[0]) / coef[1]
plt.plot(lx, ly, c ='green')
# Out:
# Testing accuracy (all training samples): 0.9371428571428572
